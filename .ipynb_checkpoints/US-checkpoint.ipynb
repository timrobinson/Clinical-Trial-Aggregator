# %%
import pandas as pd
import us
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
import numpy as np
from collections import defaultdict
import random
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
worldcities = pd.read_csv('C:/Users/robin/Programs/Myeloma/worldcities.csv')

# %%
worldcities = worldcities[worldcities['country'] == 'United States'].reset_index(drop=True)

# %%
worldcities.head()
# Out:
#           city   city_ascii      lat         lng        country iso2 iso3  \
# 0     La Jolla     La Jolla  32.8400 -117.276944  United States   US  USA
# 1     New York     New York  40.6943  -73.924900  United States   US  USA
# 2  Los Angeles  Los Angeles  34.1141 -118.406800  United States   US  USA
# 3      Chicago      Chicago  41.8375  -87.686600  United States   US  USA
# 4        Miami        Miami  25.7840  -80.210100  United States   US  USA
#
#    admin_name capital  population            id
# 0  California     NaN     46781.0           NaN
# 1    New York     NaN  18972871.0  1.840034e+09
# 2  California     NaN  12121244.0  1.840020e+09
# 3    Illinois     NaN   8595181.0  1.840000e+09
# 4     Florida     NaN   5711945.0  1.840015e+09

# %%
base = 'https://clinicaltrials.gov/ct2/results/download_fields?'

# %%
cond = 'cond=pancreatic&cancer'
term = '&term='

# %%
format_qty = '&down_fmt=csv'

# %%
include_fields = '&down_flds=all' # This can be more restrictive, but I prefer to collect all fields and downselect from there.

location = '&cntry=US&state=US%3AFL' # Florida

# To add states  -  &state=US%3AWA  - this is Washington
# To add cities  - &city=Seattle
# To add distance from city  - &dist=50
restrictions = '&recrs=ab&type=Intr'

# recrs=ab  -  this is recruiting status, a = recruiting, b = not yet recruiting, d = active not recruiting, e = completed
# age_v= (leaving blank places no restriction on age OR leave this field out of the url
# gndr= (leaving blank places no restriction on gender)
# type=Intr   - Intr is used to designate Interventional; Obsr is used for Observations; leaving blank places no restrictions on type
# phase=   - may be blank (no restrictions), 4 (early phase 1), 0 (phase 1), 1 (phase 2), 2 (phase 3), 3 (phase 4), or phase=0&phase=1 for combination
# rslt=   (With = has results; left blank or off the url means not restricted to; Without = no results)

# %%
path = (base+cond+term+format_qty+include_fields+location+restrictions)

# %%
path
# Out:
# 'https://clinicaltrials.gov/ct2/results/download_fields?cond=pancreatic&cancer&term=&down_fmt=csv&down_flds=all&cntry=US&state=US%3AFL&recrs=ab&type=Intr'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#     Rank   NCT Number                                              Title  \
# 0      1  NCT05675059  Support Through Remote Observation and Nutriti...
# 1      2  NCT04975516  Standard of Care Chemotherapy With or Without ...
# 2      3  NCT05440942  Combined MEK, STAT3 and PD-1 Inhibition in Met...
# 3      4  NCT05572788  Rectal Indomethacin to Prevent Acute Pancreati...
# 4      5  NCT06001268  Support Through Remote Observation and Nutriti...
# ..   ...          ...                                                ...
# 92    93  NCT05453578  A Phase 1b/2 Trial of the Safety and Microbiol...
# 93    94  NCT03821935  Study to Determine the Safety, Tolerability, P...
# 94    95  NCT04890613  Study of CX-5461 in Patients With Solid Tumour...
# 95    96  NCT05732831  Safety and Tolerability of TNG462 in Patients ...
# 96    97  NCT03394365  Tabelecleucel for Solid Organ or Allogeneic He...
#
#        Acronym      Status         Study Results  \
# 0          NaN  Recruiting  No Results Available
# 1          NaN  Recruiting  No Results Available
# 2          NaN  Recruiting  No Results Available
# 3          NaN  Recruiting  No Results Available
# 4   STRONG-PCS  Recruiting  No Results Available
# ..         ...         ...                   ...
# 92         NaN  Recruiting  No Results Available
# 93         NaN  Recruiting  No Results Available
# 94         NaN  Recruiting  No Results Available
# 95         NaN  Recruiting  No Results Available
# 96      ALLELE  Recruiting  No Results Available
#
#                                            Conditions  \
# 0                                   Pancreatic Cancer
# 1   Metastatic Pancreatic Adenocarcinoma|Stage IV ...
# 2                    Pancreatic Ductal Adenocarcinoma
# 3                 Pancreatic Cyst|Pancreatitis, Acute
# 4                                   Pancreatic Cancer
# ..                                                ...
# 92          Bacterial Disease Carrier|Cystic Fibrosis
# 93                       Advanced Solid Tumors Cancer
# 94                               Advanced Solid Tumor
# 95                       Locally Advanced Solid Tumor
# 96  Epstein-Barr Virus+ Associated Post-transplant...
#
#                                         Interventions  \
# 0   Behavioral: Consultations with Moffitt Dietici...
# 1   Drug: Chemotherapy|Radiation: Stereotactic Bod...
# 2   Drug: Trametinib|Drug: Ruxolitinib|Drug: Retif...
# 3   Procedure: EUS-guided fine needle aspiration o...
# 4   Behavioral: Fitbit Data Collection|Behavioral:...
# ..                                                ...
# 92           Other: Placebo|Biological: WRAIR-PAM-CF1
# 93              Drug: Livmoniplimab|Drug: Budigalimab
# 94                                      Drug: CX-5461
# 95                                       Drug: TNG462
# 96                          Biological: tabelecleucel
#
#                                      Outcome Measures  \
# 0   Feasibility of the STRONG Program|Acceptabilit...
# 1   Progression free survival|Confirmed response r...
# 2   Recommended Phase 2 Dose (RP2D)|Incidence of T...
# 3   Rate of post-procedure pancreatitis following ...
# 4   Recruitment Rate - Feasibility|Retention Rate ...
# ..                                                ...
# 92  Change from baseline in log10 P. aeruginosa to...
# 93  Dose Escalation: Recommended Phase 2 Dose (RP2...
# 94  Determination of Recommended Phase 2 Dose (RP2...
# 95  Phase 1 Maximum Tolerated Dose|Phase 1 Dosing ...
# 96  Objective response rate (ORR) in the SOT or HC...
#
#                                 Sponsor/Collaborators  ...  \
# 0   H. Lee Moffitt Cancer Center and Research Inst...  ...
# 1                                         Mayo Clinic  ...
# 2   Peter Hosein, MD|Incyte Corporation|Novartis P...  ...
# 3                                Orlando Health, Inc.  ...
# 4   H. Lee Moffitt Cancer Center and Research Inst...  ...
# ..                                                ...  ...
# 92  National Institute of Allergy and Infectious D...  ...
# 93                                             AbbVie  ...
# 94                           Senhwa Biosciences, Inc.  ...
# 95                           Tango Therapeutics, Inc.  ...
# 96                              Atara Biotherapeutics  ...
#
#                             Other IDs          Start Date  \
# 0                           MCC-22082   December 21, 2022
# 1   MC210711|NCI-2021-07006|20-011610       July 18, 2023
# 2                            20220171    January 19, 2023
# 3                   22.085.04|1894054  September 26, 2022
# 4                           MCC-22476     August 14, 2023
# ..                                ...                 ...
# 92            20-0001|5UM1AI104681-12     October 3, 2022
# 93             M19-345|2018-004303-40   February 21, 2019
# 94                         CX-5461-04   September 8, 2021
# 95                        TNG462-C101        May 26, 2023
# 96                     ATA129-EBV-302   December 29, 2017
#
#    Primary Completion Date  Completion Date       First Posted  \
# 0            December 2024    December 2024    January 9, 2023
# 1             July 2, 2026     July 2, 2027      July 23, 2021
# 2               March 2025   September 2027       July 1, 2022
# 3                July 2025    December 2025   October 10, 2022
# 4              August 2027      August 2027    August 21, 2023
# ..                     ...              ...                ...
# 92           June 28, 2024    June 28, 2024      July 12, 2022
# 93       February 19, 2026    June 23, 2027   January 30, 2019
# 94           December 2024        June 2025       May 18, 2021
# 95                May 2026   September 2026  February 17, 2023
# 96               June 2022        June 2027    January 9, 2018
#
#    Results First Posted Last Update Posted  \
# 0                   NaN     March 19, 2024
# 1                   NaN      March 8, 2024
# 2                   NaN  November 28, 2023
# 3                   NaN   January 31, 2024
# 4                   NaN  February 13, 2024
# ..                  ...                ...
# 92                  NaN     March 22, 2024
# 93                  NaN     March 12, 2024
# 94                  NaN    January 3, 2024
# 95                  NaN    January 5, 2024
# 96                  NaN      June 24, 2022
#
#                                             Locations Study Documents  \
# 0   Moffitt Cancer Center, Tampa, Florida, United ...             NaN
# 1   Mayo Clinic in Florida, Jacksonville, Florida,...             NaN
# 2   University of Miami, Miami, Florida, United St...             NaN
# 3     Orlando Health, Orlando, Florida, United States             NaN
# 4   Moffitt Cancer Center, Tampa, Florida, United ...             NaN
# ..                                                ...             ...
# 92  University of California, San Diego, La Jolla,...             NaN
# 93  Yale University /ID# 208356, New Haven, Connec...             NaN
# 94  University of California, Los Angeles, Santa M...             NaN
# 95  Sylvester Comprehensive Cancer Center, Miami, ...             NaN
# 96  City of Hope (Adults and Pediatrics), Duarte, ...             NaN
#
#                                             URL
# 0   https://ClinicalTrials.gov/show/NCT05675059
# 1   https://ClinicalTrials.gov/show/NCT04975516
# 2   https://ClinicalTrials.gov/show/NCT05440942
# 3   https://ClinicalTrials.gov/show/NCT05572788
# 4   https://ClinicalTrials.gov/show/NCT06001268
# ..                                          ...
# 92  https://ClinicalTrials.gov/show/NCT05453578
# 93  https://ClinicalTrials.gov/show/NCT03821935
# 94  https://ClinicalTrials.gov/show/NCT04890613
# 95  https://ClinicalTrials.gov/show/NCT05732831
# 96  https://ClinicalTrials.gov/show/NCT03394365
#
# [97 rows x 27 columns]

# %%
df.Locations[0]
# Out:
# 'Moffitt Cancer Center, Tampa, Florida, United States'

# %%
color = ['#ff00ff', '#fe01ff', '#fd02ff', '#fc03ff', '#fb04ff', '#fa05ff', '#f906ff', '#f807ff', '#f708ff', '#f609ff', '#f50aff', '#f40bff', '#f30cff', '#f20dff', '#f10eff', '#f00fff', '#ef10ff', '#ee11ff', '#ed12ff', '#ec13ff', '#eb14ff', '#ea15ff', '#e916ff', '#e817ff', '#e718ff', '#e61aff', '#e41bff', '#e31cff', '#e21dff', '#e11eff', '#e01fff', '#df20ff', '#de21ff', '#dd22ff', '#dc23ff', '#db24ff', '#da25ff', '#d926ff', '#d827ff', '#d728ff', '#d629ff', '#d52aff', '#d42bff', '#d32cff', '#d22dff', '#d12eff', '#d02fff', '#cf30ff', '#ce31ff', '#cd32ff', '#cc33ff', '#cb34ff', '#ca35ff', '#c936ff', '#c837ff', '#c738ff', '#c639ff', '#c53aff', '#c43bff', '#c33cff', '#c23dff', '#c13eff', '#c03fff', '#bf40ff', '#be41ff', '#bd42ff', '#bc43ff', '#bb44ff', '#ba45ff', '#b946ff', '#b847ff', '#b748ff', '#b649ff', '#b54aff', '#b44bff', '#b34dff', '#b14eff', '#b04fff', '#af50ff', '#ae51ff', '#ad52ff', '#ac53ff', '#ab54ff', '#aa55ff', '#a956ff', '#a857ff', '#a758ff', '#a659ff', '#a55aff', '#a45bff', '#a35cff', '#a25dff', '#a15eff', '#a05fff', '#9f60ff', '#9e61ff', '#9d62ff', '#9c63ff', '#9b64ff', '#9a65ff', '#9966ff', '#9867ff', '#9768ff', '#9669ff', '#956aff', '#946bff', '#936cff', '#926dff', '#916eff', '#906fff', '#8f70ff', '#8e71ff', '#8d72ff', '#8c73ff', '#8b74ff', '#8a75ff', '#8976ff', '#8877ff', '#8778ff', '#8679ff', '#857aff', '#847bff', '#837cff', '#827dff', '#817eff', '#8080ff', '#7e81ff', '#7d82ff', '#7c83ff', '#7b84ff', '#7a85ff', '#7986ff', '#7887ff', '#7788ff', '#7689ff', '#758aff', '#748bff', '#738cff', '#728dff', '#718eff', '#708fff', '#6f90ff', '#6e91ff', '#6d92ff', '#6c93ff', '#6b94ff', '#6a95ff', '#6996ff', '#6897ff', '#6798ff', '#6699ff', '#659aff', '#649bff', '#639cff', '#629dff', '#619eff', '#609fff', '#5fa0ff', '#5ea1ff', '#5da2ff', '#5ca3ff', '#5ba4ff', '#5aa5ff', '#59a6ff', '#58a7ff', '#57a8ff', '#56a9ff', '#55aaff', '#54abff', '#53acff', '#52adff', '#51aeff', '#50afff', '#4fb0ff', '#4eb1ff', '#4db3ff', '#4bb4ff', '#4ab5ff', '#49b6ff', '#48b7ff', '#47b8ff', '#46b9ff', '#45baff', '#44bbff', '#43bcff', '#42bdff', '#41beff', '#40bfff', '#3fc0ff', '#3ec1ff', '#3dc2ff', '#3cc3ff', '#3bc4ff', '#3ac5ff', '#39c6ff', '#38c7ff', '#37c8ff', '#36c9ff', '#35caff', '#34cbff', '#33ccff', '#32cdff', '#31ceff', '#30cfff', '#2fd0ff', '#2ed1ff', '#2dd2ff', '#2cd3ff', '#2bd4ff', '#2ad5ff', '#29d6ff', '#28d7ff', '#27d8ff', '#26d9ff', '#25daff', '#24dbff', '#23dcff', '#22ddff', '#21deff', '#20dfff', '#1fe0ff', '#1ee1ff', '#1de2ff', '#1ce3ff', '#1be4ff', '#1ae6ff', '#18e7ff', '#17e8ff', '#16e9ff', '#15eaff', '#14ebff', '#13ecff', '#12edff', '#11eeff', '#10efff', '#0ff0ff', '#0ef1ff', '#0df2ff', '#0cf3ff', '#0bf4ff', '#0af5ff', '#09f6ff', '#08f7ff', '#07f8ff', '#06f9ff', '#05faff', '#04fbff', '#03fcff', '#02fdff', '#01feff', '#00ffff', '#01fffe', '#02fefd', '#03fefc', '#04fefb', '#05fdfa', '#06fdf9', '#07fcf8', '#08fcf7', '#09fcf6', '#0afbf5', '#0bfbf4', '#0cfbf3', '#0dfaf2', '#0efaf1', '#0ffaf0', '#10f9ef', '#11f9ee', '#12f9ed', '#13f8ec', '#14f8eb', '#15f7ea', '#16f7e9', '#17f7e8', '#18f6e7', '#1af6e5', '#1bf6e4', '#1cf5e3', '#1df5e2', '#1ef5e1', '#1ff4e0', '#20f4df', '#21f3de', '#22f3dd', '#23f3dc', '#24f2db', '#25f2da', '#26f2d9', '#27f1d8', '#28f1d7', '#29f1d6', '#2af0d5', '#2bf0d4', '#2cf0d3', '#2defd2', '#2eefd1', '#2feed0', '#30eecf', '#31eece', '#32edcd', '#33edcc', '#34edcb', '#35ecca', '#36ecc9', '#37ecc8', '#38ebc7', '#39ebc6', '#3aeac5', '#3beac4', '#3ceac3', '#3de9c2', '#3ee9c1', '#3fe9c0', '#40e8bf', '#41e8be', '#42e8bd', '#43e7bc', '#44e7bb', '#45e7ba', '#46e6b9', '#47e6b8', '#48e5b7', '#49e5b6', '#4ae5b5', '#4be4b4', '#4de4b3', '#4ee4b1', '#4fe3b0', '#50e3af', '#51e3ae', '#52e2ad', '#53e2ac', '#54e1ab', '#55e1aa', '#56e1a9', '#57e0a8', '#58e0a7', '#59e0a6', '#5adfa5', '#5bdfa4', '#5cdfa3', '#5ddea2', '#5edea1', '#5fdea0', '#60dd9f', '#61dd9e', '#62dc9d', '#63dc9c', '#64dc9b', '#65db9a', '#66db99', '#67db98', '#68da97', '#69da96', '#6ada95', '#6bd994', '#6cd993', '#6dd892', '#6ed891', '#6fd890', '#70d78f', '#71d78e', '#72d78d', '#73d68c', '#74d68b', '#75d68a', '#76d589', '#77d588', '#78d587', '#79d486', '#7ad485', '#7bd384', '#7cd383', '#7dd382', '#7ed281', '#80d280', '#81d27e', '#82d17d', '#83d17c', '#84d17b', '#85d07a', '#86d079', '#87cf78', '#88cf77', '#89cf76', '#8ace75', '#8bce74', '#8cce73', '#8dcd72', '#8ecd71', '#8fcd70', '#90cc6f', '#91cc6e', '#92cc6d', '#93cb6c', '#94cb6b', '#95ca6a', '#96ca69', '#97ca68', '#98c967', '#99c966', '#9ac965', '#9bc864', '#9cc863', '#9dc862', '#9ec761', '#9fc760', '#a0c65f', '#a1c65e', '#a2c65d', '#a3c55c', '#a4c55b', '#a5c55a', '#a6c459', '#a7c458', '#a8c457', '#a9c356', '#aac355', '#abc354', '#acc253', '#adc252', '#aec151', '#afc150', '#b0c14f', '#b1c04e', '#b3c04d', '#b4c04b', '#b5bf4a', '#b6bf49', '#b7bf48', '#b8be47', '#b9be46', '#babd45', '#bbbd44', '#bcbd43', '#bdbc42', '#bebc41', '#bfbc40', '#c0bb3f', '#c1bb3e', '#c2bb3d', '#c3ba3c', '#c4ba3b', '#c5ba3a', '#c6b939', '#c7b938', '#c8b837', '#c9b836', '#cab835', '#cbb734', '#ccb733', '#cdb732', '#ceb631', '#cfb630', '#d0b62f', '#d1b52e', '#d2b52d', '#d3b42c', '#d4b42b', '#d5b42a', '#d6b329', '#d7b328', '#d8b327', '#d9b226', '#dab225', '#dbb224', '#dcb123', '#ddb122', '#deb121', '#dfb020', '#e0b01f', '#e1af1e', '#e2af1d', '#e3af1c', '#e4ae1b', '#e5ae1a', '#e7ae18', '#e8ad17', '#e9ad16', '#eaad15', '#ebac14', '#ecac13', '#edab12', '#eeab11', '#efab10', '#f0aa0f', '#f1aa0e', '#f2aa0d', '#f3a90c', '#f4a90b', '#f5a90a', '#f6a809', '#f7a808', '#f8a807', '#f9a706', '#faa705', '#fba604', '#fca603', '#fda602', '#fea501', '#fffedf', '#fffddf', '#fffcde', '#fffbde', '#fffadd', '#fff9dd', '#fff8dc', '#fff7dc', '#fff6db', '#fff5db', '#fff4da', '#fff3da', '#fff2d9', '#fff1d9', '#fff0d8', '#ffefd8', '#ffeed7', '#ffedd7', '#ffecd6', '#ffebd6', '#ffead5', '#ffe9d5', '#ffe8d4', '#ffe7d4', '#ffe6d3', '#ffe4d2', '#ffe3d2', '#ffe2d1', '#ffe1d1', '#ffe0d0', '#ffdfd0', '#ffdecf', '#ffddcf', '#ffdcce', '#ffdbce', '#ffdacd', '#ffd9cd', '#ffd8cc', '#ffd7cc', '#ffd6cb', '#ffd5cb', '#ffd4ca', '#ffd3ca', '#ffd2c9', '#ffd1c9', '#ffd0c8', '#ffcfc8', '#ffcec7', '#ffcdc7', '#ffccc6', '#ffcbc5', '#ffcac5', '#ffc9c4', '#ffc8c4', '#ffc7c3', '#ffc6c3', '#ffc5c2', '#ffc4c2', '#ffc3c1', '#ffc2c1', '#ffc1c0', '#ffc0c0', '#ffbfbf', '#ffbebf', '#ffbdbe', '#ffbcbe', '#ffbbbd', '#ffbabd', '#ffb9bc', '#ffb8bc', '#ffb7bb', '#ffb6bb', '#ffb5ba', '#ffb4ba', '#ffb3b9', '#ffb1b8', '#ffb0b8', '#ffafb7', '#ffaeb7', '#ffadb6', '#ffacb6', '#ffabb5', '#ffaab5', '#ffa9b4', '#ffa8b4', '#ffa7b3', '#ffa6b3', '#ffa5b2', '#ffa4b2', '#ffa3b1', '#ffa2b1', '#ffa1b0', '#ffa0b0', '#ff9faf', '#ff9eaf', '#ff9dae', '#ff9cae', '#ff9bad', '#ff9aad', '#ff99ac', '#ff98ab', '#ff97ab', '#ff96aa', '#ff95aa', '#ff94a9', '#ff93a9', '#ff92a8', '#ff91a8', '#ff90a7', '#ff8fa7', '#ff8ea6', '#ff8da6', '#ff8ca5', '#ff8ba5', '#ff8aa4', '#ff89a4', '#ff88a3', '#ff87a3', '#ff86a2', '#ff85a2', '#ff84a1', '#ff83a1', '#ff82a0', '#ff81a0', '#ff809f', '#ff7e9e', '#ff7d9e', '#ff7c9d', '#ff7b9d', '#ff7a9c', '#ff799c', '#ff789b', '#ff779b', '#ff769a', '#ff759a', '#ff7499', '#ff7399', '#ff7298', '#ff7198', '#ff7097', '#ff6f97', '#ff6e96', '#ff6d96', '#ff6c95', '#ff6b95', '#ff6a94', '#ff6994', '#ff6893', '#ff6793', '#ff6692', '#ff6591', '#ff6491', '#ff6390', '#ff6290', '#ff618f', '#ff608f', '#ff5f8e', '#ff5e8e', '#ff5d8d', '#ff5c8d', '#ff5b8c', '#ff5a8c', '#ff598b', '#ff588b', '#ff578a', '#ff568a', '#ff5589', '#ff5489', '#ff5388', '#ff5288', '#ff5187', '#ff5087', '#ff4f86', '#ff4e86', '#ff4d85', '#ff4b84', '#ff4a84', '#ff4983', '#ff4883', '#ff4782', '#ff4682', '#ff4581', '#ff4481', '#ff4380', '#ff4280', '#ff417f', '#ff407f', '#ff3f7e', '#ff3e7e', '#ff3d7d', '#ff3c7d', '#ff3b7c', '#ff3a7c', '#ff397b', '#ff387b', '#ff377a', '#ff367a', '#ff3579', '#ff3479', '#ff3378', '#ff3277', '#ff3177', '#ff3076', '#ff2f76', '#ff2e75', '#ff2d75', '#ff2c74', '#ff2b74', '#ff2a73', '#ff2973', '#ff2872', '#ff2772', '#ff2671', '#ff2571', '#ff2470', '#ff2370', '#ff226f', '#ff216f', '#ff206e', '#ff1f6e', '#ff1e6d', '#ff1d6d', '#ff1c6c', '#ff1b6c', '#ff1a6b', '#ff186a', '#ff176a', '#ff1669', '#ff1569', '#ff1468', '#ff1368', '#ff1267', '#ff1167', '#ff1066', '#ff0f66', '#ff0e65', '#ff0d65', '#ff0c64', '#ff0b64', '#ff0a63', '#ff0963', '#ff0862', '#ff0762', '#ff0661', '#ff0561', '#ff0460', '#ff0360', '#ff025f', '#ff015f', '#ff005e', '#ff005e', '#fe005e', '#fe005e', '#fd005d', '#fd005d', '#fc005d', '#fc005d', '#fc005d', '#fb005d', '#fb005d', '#fa005c', '#fa005c', '#f9005c', '#f9005c', '#f9005c', '#f8005c', '#f8005c', '#f7005b', '#f7005b', '#f6005b', '#f6005b', '#f5005b', '#f5005b', '#f5005b', '#f4005a', '#f4005a', '#f3005a', '#f3005a', '#f2005a', '#f2005a', '#f2005a', '#f10059', '#f10059', '#f00059', '#f00059', '#ef0059', '#ef0059', '#ef0059', '#ee0058', '#ee0058', '#ed0058', '#ed0058', '#ec0058', '#ec0058', '#ec0058', '#eb0057', '#eb0057', '#ea0057', '#ea0057', '#e90057', '#e90057', '#e90057', '#e80056', '#e80056', '#e70056', '#e70056', '#e60056', '#e60056', '#e60056', '#e50055', '#e50055', '#e40055', '#e40055', '#e30055', '#e30055', '#e20054', '#e20054', '#e20054', '#e10054', '#e10054', '#e00054', '#e00054', '#df0053', '#df0053', '#df0053', '#de0053', '#de0053', '#dd0053', '#dd0053', '#dc0052', '#dc0052', '#dc0052', '#db0052', '#db0052', '#da0052', '#da0052', '#d90051', '#d90051', '#d90051', '#d80051', '#d80051', '#d70051', '#d70051', '#d60050', '#d60050', '#d60050', '#d50050', '#d50050', '#d40050', '#d40050', '#d3004f', '#d3004f', '#d3004f', '#d2004f', '#d2004f', '#d1004f', '#d1004f', '#d0004e', '#d0004e', '#cf004e', '#cf004e', '#cf004e', '#ce004e', '#ce004e', '#cd004d', '#cd004d', '#cc004d', '#cc004d', '#cc004d', '#cb004d', '#cb004d', '#ca004c', '#ca004c', '#c9004c', '#c9004c', '#c9004c', '#c8004c', '#c8004c', '#c7004b', '#c7004b', '#c6004b', '#c6004b', '#c6004b', '#c5004b', '#c5004b', '#c4004a', '#c4004a', '#c3004a', '#c3004a', '#c3004a', '#c2004a', '#c2004a', '#c10049', '#c10049', '#c00049', '#c00049', '#bf0049', '#bf0049', '#bf0049', '#be0048', '#be0048', '#bd0048', '#bd0048', '#bc0048', '#bc0048', '#bc0048', '#bb0047', '#bb0047', '#ba0047', '#ba0047', '#b90047', '#b90047', '#b90047', '#b80046', '#b80046', '#b70046', '#b70046', '#b60046', '#b60046', '#b60046', '#b50045', '#b50045', '#b40045', '#b40045', '#b30045', '#b30045', '#b30045', '#b20044', '#b20044', '#b10044', '#b10044', '#b00044', '#b00044', '#b00044', '#af0043', '#af0043', '#ae0043', '#ae0043', '#ad0043', '#ad0043', '#ac0042', '#ac0042', '#ac0042', '#ab0042', '#ab0042', '#aa0042', '#aa0042', '#a90041', '#a90041', '#a90041', '#a80041', '#a80041', '#a70041', '#a70041', '#a60040', '#a60040', '#a60040', '#a50040', '#a50040', '#a40040', '#a40040', '#a3003f', '#a3003f', '#a3003f', '#a2003f', '#a2003f', '#a1003f', '#a1003f', '#a0003e', '#a0003e', '#a0003e', '#9f003e', '#9f003e', '#9e003e', '#9e003e', '#9d003d', '#9d003d', '#9d003d', '#9c003d', '#9c003d', '#9b003d', '#9b003d', '#9a003c', '#9a003c', '#99003c', '#99003c', '#99003c', '#98003c', '#98003c', '#97003b', '#97003b', '#96003b', '#96003b', '#96003b', '#95003b', '#95003b', '#94003a', '#94003a', '#93003a', '#93003a']

# %%
increment = int(len(color)/len(df))

# %%
# len(df), len(color[::increment][:len(df)])

# %%
df['Color'] = random.sample(color[::increment][:len(df)], len(color[::increment][:len(df)]))

# %%
# df.Locations[0].split('|')

# %%
df.Locations = [df.Locations[i].split('|') for i in range(len(df.Locations))]

# %%
# df.Locations[0]

# %%
df = df.explode('Locations').reset_index(drop=True)

# %%
df.Locations = [df.Locations[i].split(',') for i in range(len(df.Locations))]

# %%
facilities = [df.Locations[i][0] for i in range(len(df.Locations))]

# %%
df['Facilities'] = facilities

# %%
# [print(df.Locations[i][1:]) for i in range(len(df.Locations))]

# %%
country = [df.Locations[i][-1][1:] for i in range(len(df.Locations))]

# %%
df['Country'] = country

# %%
df = df[df['Country'] == 'United States'].reset_index(drop=True)

# %%
geotemp = [df.Locations[i][1:-1] for i in range(len(df.Locations))]

df['City'] = [[df.Locations[i][1:-1] for i in range(len(df.Locations))][j][-2][1:] for j in range(len(df.Locations))]

# %%
cities = [geotemp[i][-2][1:] for i in range(len(geotemp))]
state = [geotemp[i][-1][1:] for i in range(len(geotemp))]

# %%
df['City'] = cities
df['State'] = state

# %%
df
# Out:
#       Rank   NCT Number                                              Title  \
# 0        1  NCT05675059  Support Through Remote Observation and Nutriti...
# 1        2  NCT04975516  Standard of Care Chemotherapy With or Without ...
# 2        3  NCT05440942  Combined MEK, STAT3 and PD-1 Inhibition in Met...
# 3        4  NCT05572788  Rectal Indomethacin to Prevent Acute Pancreati...
# 4        5  NCT06001268  Support Through Remote Observation and Nutriti...
# ...    ...          ...                                                ...
# 3271    97  NCT03394365  Tabelecleucel for Solid Organ or Allogeneic He...
# 3272    97  NCT03394365  Tabelecleucel for Solid Organ or Allogeneic He...
# 3273    97  NCT03394365  Tabelecleucel for Solid Organ or Allogeneic He...
# 3274    97  NCT03394365  Tabelecleucel for Solid Organ or Allogeneic He...
# 3275    97  NCT03394365  Tabelecleucel for Solid Organ or Allogeneic He...
#
#          Acronym      Status         Study Results  \
# 0            NaN  Recruiting  No Results Available
# 1            NaN  Recruiting  No Results Available
# 2            NaN  Recruiting  No Results Available
# 3            NaN  Recruiting  No Results Available
# 4     STRONG-PCS  Recruiting  No Results Available
# ...          ...         ...                   ...
# 3271      ALLELE  Recruiting  No Results Available
# 3272      ALLELE  Recruiting  No Results Available
# 3273      ALLELE  Recruiting  No Results Available
# 3274      ALLELE  Recruiting  No Results Available
# 3275      ALLELE  Recruiting  No Results Available
#
#                                              Conditions  \
# 0                                     Pancreatic Cancer
# 1     Metastatic Pancreatic Adenocarcinoma|Stage IV ...
# 2                      Pancreatic Ductal Adenocarcinoma
# 3                   Pancreatic Cyst|Pancreatitis, Acute
# 4                                     Pancreatic Cancer
# ...                                                 ...
# 3271  Epstein-Barr Virus+ Associated Post-transplant...
# 3272  Epstein-Barr Virus+ Associated Post-transplant...
# 3273  Epstein-Barr Virus+ Associated Post-transplant...
# 3274  Epstein-Barr Virus+ Associated Post-transplant...
# 3275  Epstein-Barr Virus+ Associated Post-transplant...
#
#                                           Interventions  \
# 0     Behavioral: Consultations with Moffitt Dietici...
# 1     Drug: Chemotherapy|Radiation: Stereotactic Bod...
# 2     Drug: Trametinib|Drug: Ruxolitinib|Drug: Retif...
# 3     Procedure: EUS-guided fine needle aspiration o...
# 4     Behavioral: Fitbit Data Collection|Behavioral:...
# ...                                                 ...
# 3271                          Biological: tabelecleucel
# 3272                          Biological: tabelecleucel
# 3273                          Biological: tabelecleucel
# 3274                          Biological: tabelecleucel
# 3275                          Biological: tabelecleucel
#
#                                        Outcome Measures  \
# 0     Feasibility of the STRONG Program|Acceptabilit...
# 1     Progression free survival|Confirmed response r...
# 2     Recommended Phase 2 Dose (RP2D)|Incidence of T...
# 3     Rate of post-procedure pancreatitis following ...
# 4     Recruitment Rate - Feasibility|Retention Rate ...
# ...                                                 ...
# 3271  Objective response rate (ORR) in the SOT or HC...
# 3272  Objective response rate (ORR) in the SOT or HC...
# 3273  Objective response rate (ORR) in the SOT or HC...
# 3274  Objective response rate (ORR) in the SOT or HC...
# 3275  Objective response rate (ORR) in the SOT or HC...
#
#                                   Sponsor/Collaborators  ...  \
# 0     H. Lee Moffitt Cancer Center and Research Inst...  ...
# 1                                           Mayo Clinic  ...
# 2     Peter Hosein, MD|Incyte Corporation|Novartis P...  ...
# 3                                  Orlando Health, Inc.  ...
# 4     H. Lee Moffitt Cancer Center and Research Inst...  ...
# ...                                                 ...  ...
# 3271                              Atara Biotherapeutics  ...
# 3272                              Atara Biotherapeutics  ...
# 3273                              Atara Biotherapeutics  ...
# 3274                              Atara Biotherapeutics  ...
# 3275                              Atara Biotherapeutics  ...
#
#      Results First Posted Last Update Posted  \
# 0                     NaN     March 19, 2024
# 1                     NaN      March 8, 2024
# 2                     NaN  November 28, 2023
# 3                     NaN   January 31, 2024
# 4                     NaN  February 13, 2024
# ...                   ...                ...
# 3271                  NaN      June 24, 2022
# 3272                  NaN      June 24, 2022
# 3273                  NaN      June 24, 2022
# 3274                  NaN      June 24, 2022
# 3275                  NaN      June 24, 2022
#
#                                               Locations  Study Documents  \
# 0     [Moffitt Cancer Center,  Tampa,  Florida,  Uni...              NaN
# 1     [Mayo Clinic in Florida,  Jacksonville,  Flori...              NaN
# 2     [University of Miami,  Miami,  Florida,  Unite...              NaN
# 3     [Orlando Health,  Orlando,  Florida,  United S...              NaN
# 4     [Moffitt Cancer Center,  Tampa,  Florida,  Uni...              NaN
# ...                                                 ...              ...
# 3271  [Vanderbilt University Medical Center Henry-Jo...              NaN
# 3272  [Baylor Scott and White Research Institute (Ad...              NaN
# 3273  [University of Texas Southwestern Medical Cent...              NaN
# 3274  [MD Anderson Cancer Center (Adults and Pediatr...              NaN
# 3275  [Froedtert Hospital & the Medical College of W...              NaN
#
#                                               URL    Color  \
# 0     https://ClinicalTrials.gov/show/NCT05675059  #7a85ff
# 1     https://ClinicalTrials.gov/show/NCT04975516  #ff8ea6
# 2     https://ClinicalTrials.gov/show/NCT05440942  #ffcbc5
# 3     https://ClinicalTrials.gov/show/NCT05572788  #ffa2b1
# 4     https://ClinicalTrials.gov/show/NCT06001268  #cc33ff
# ...                                           ...      ...
# 3271  https://ClinicalTrials.gov/show/NCT03394365  #ad52ff
# 3272  https://ClinicalTrials.gov/show/NCT03394365  #ad52ff
# 3273  https://ClinicalTrials.gov/show/NCT03394365  #ad52ff
# 3274  https://ClinicalTrials.gov/show/NCT03394365  #ad52ff
# 3275  https://ClinicalTrials.gov/show/NCT03394365  #ad52ff
#
#                                              Facilities        Country  \
# 0                                 Moffitt Cancer Center  United States
# 1                                Mayo Clinic in Florida  United States
# 2                                   University of Miami  United States
# 3                                        Orlando Health  United States
# 4                                 Moffitt Cancer Center  United States
# ...                                                 ...            ...
# 3271  Vanderbilt University Medical Center Henry-Joy...  United States
# 3272  Baylor Scott and White Research Institute (Adu...  United States
# 3273  University of Texas Southwestern Medical Cente...  United States
# 3274  MD Anderson Cancer Center (Adults and Pediatrics)  United States
# 3275  Froedtert Hospital & the Medical College of Wi...  United States
#
#               City      State
# 0            Tampa    Florida
# 1     Jacksonville    Florida
# 2            Miami    Florida
# 3          Orlando    Florida
# 4            Tampa    Florida
# ...            ...        ...
# 3271     Nashville  Tennessee
# 3272        Dallas      Texas
# 3273        Dallas      Texas
# 3274       Houston      Texas
# 3275     Milwaukee  Wisconsin
#
# [3276 rows x 32 columns]

# %%
set(df.City).difference(worldcities.city)
# Out:
# {'Aitkin',
#  'Antigo',
#  'Atlantis',
#  'Basking Ridge',
#  'Belpre',
#  'Boardman',
#  'Brownstown',
#  'Bryn Mawr',
#  'Caro',
#  'Carterville',
#  'Clackamas',
#  'Clinton Township',
#  'Collegeville',
#  'Corbin',
#  'Creston',
#  'Deer River',
#  'East China Township',
#  'East Hills',
#  'East Syracuse',
#  'Ely',
#  'Emmett',
#  'Exton',
#  'Fairway',
#  'Fosston',
#  'Frankford',
#  'Fruitland',
#  'Gettysburg',
#  'International Falls',
#  'Johnson Creek',
#  'Kenansville',
#  'Kingwood',
#  'Ladysmith',
#  'Lake Success',
#  'Manhasset',
#  'Marlette',
#  'Media',
#  'Mickleton',
#  'Minocqua',
#  'Montvale',
#  'Moose Lake',
#  'Mount Sterling',
#  'Mukwonago',
#  'North Kansas City',
#  'Paoli',
#  'Park Rapids',
#  'Pennington',
#  'Port Jefferson Station',
#  'Reed City',
#  'Rego Park',
#  'Rehoboth Beach',
#  'Richlands',
#  'Saint Johnsbury',
#  'Saint Joseph',
#  'Saint Louis',
#  'Saint Louis Park',
#  'Saint Paul',
#  'Saint Petersburg',
#  'Sainte Genevieve',
#  'Sandpoint',
#  'Sandstone',
#  'Sayre',
#  'Shavano Park',
#  'Southhaven',
#  'Spooner',
#  'Tawas City',
#  'Valhalla',
#  'Virginia',
#  'West Bloomfield',
#  'West Branch',
#  'West Reading',
#  'Wexford',
#  'Wynnewood'}

# %%
# df[df.City == 'Saint Louis']

# %%
# worldcities[worldcities.admin_name == 'Missouri'].city.to_list()[0]

# %%
# df.City = df.City.replace(['Saint Louis'], 'St. Louis')

# %%
not_listed = list(set(df.City).difference(worldcities.city))

# %%
not_listed
# Out:
# ['Mukwonago',
#  'International Falls',
#  'Spooner',
#  'Saint Paul',
#  'Atlantis',
#  'Moose Lake',
#  'Sandstone',
#  'Clackamas',
#  'Brownstown',
#  'Port Jefferson Station',
#  'Saint Louis Park',
#  'Johnson Creek',
#  'Valhalla',
#  'West Branch',
#  'Saint Petersburg',
#  'Basking Ridge',
#  'Montvale',
#  'Sayre',
#  'Wynnewood',
#  'Antigo',
#  'Kingwood',
#  'Paoli',
#  'Wexford',
#  'Ely',
#  'West Bloomfield',
#  'Emmett',
#  'Belpre',
#  'Marlette',
#  'Bryn Mawr',
#  'Kenansville',
#  'Pennington',
#  'Shavano Park',
#  'Aitkin',
#  'Saint Louis',
#  'Fosston',
#  'Reed City',
#  'Virginia',
#  'Manhasset',
#  'Media',
#  'Ladysmith',
#  'Saint Joseph',
#  'Corbin',
#  'Mount Sterling',
#  'Frankford',
#  'Boardman',
#  'Richlands',
#  'Mickleton',
#  'Sainte Genevieve',
#  'Caro',
#  'Fruitland',
#  'Park Rapids',
#  'Lake Success',
#  'Exton',
#  'Rehoboth Beach',
#  'Creston',
#  'Sandpoint',
#  'Tawas City',
#  'Fairway',
#  'Rego Park',
#  'Southhaven',
#  'Minocqua',
#  'Gettysburg',
#  'Saint Johnsbury',
#  'East China Township',
#  'West Reading',
#  'North Kansas City',
#  'East Hills',
#  'Carterville',
#  'Clinton Township',
#  'East Syracuse',
#  'Deer River',
#  'Collegeville']

# %%
geolocator = Nominatim(user_agent='MMFighters')

# %%
x, y = [], []

for city in not_listed:
    state  = us.states.lookup(df.State[df.City == city][df.State[df.City == city].index[0]])
    loc = geolocator.geocode(city +' ' + state.abbr)
    x.append(np.round(loc.longitude, 4))
    y.append(np.round(loc.latitude, 4))
    
x
# Out:
# [-88.3334,
#  -93.4106,
#  -91.8909,
#  -93.0931,
#  -80.1009,
#  -92.762,
#  -92.8674,
#  -122.2305,
#  -88.9528,
#  -73.0652,
#  -93.3569,
#  -88.7743,
#  -73.7751,
#  -91.346,
#  -82.6359,
#  -74.5493,
#  -74.0229,
#  -76.5155,
#  -75.2707,
#  -89.1523,
#  -95.1846,
#  -75.4928,
#  -80.0559,
#  -91.8572,
#  -77.5392,
#  -116.4993,
#  -81.5758,
#  -83.0802,
#  -75.3173,
#  -77.9622,
#  -74.791,
#  -98.5525,
#  -93.3848,
#  -90.191,
#  -95.7514,
#  -85.5101,
#  -92.5366,
#  -73.6989,
#  -75.3877,
#  -91.1009,
#  -94.8466,
#  -84.0969,
#  -83.9432,
#  -75.2338,
#  -80.6629,
#  -77.5466,
#  -75.2377,
#  -90.1857,
#  -83.3969,
#  -116.9165,
#  -95.0586,
#  -73.7176,
#  -75.6208,
#  -75.0835,
#  -94.3614,
#  -116.5532,
#  -83.5147,
#  -94.6319,
#  -73.8621,
#  -90.857,
#  -89.711,
#  -77.231,
#  -72.0157,
#  -82.4834,
#  -75.9474,
#  -94.5734,
#  -73.6241,
#  -89.0773,
#  -82.92,
#  -76.0785,
#  -93.7928,
#  -75.4516]

# %%
for i in not_listed:
    df = df[df.City != i].reset_index(drop=True)

# %%
# lat, lon = [], []

# for i in range(len(df.City)):
#     for j in range(len(worldcities.city)):
#         if (df.City[i], df.State[i]) == (worldcities.city[j], worldcities.admin_name[j]):
#             lat.append(worldcities.lat[j])
#             lon.append(worldcities.lng[j])

# %%
merged_df = pd.merge(df, worldcities[['city', 'admin_name', 'lat', 'lng']], left_on=['City', 'State'], right_on=['city', 'admin_name'], how='left')

lat = merged_df['lat'].tolist()

lon = merged_df['lng'].tolist()

# %%
set(merged_df.City).difference(worldcities.city), len(merged_df)
# Out:
# (set(), 3085)

# %%
# merged_df[merged_df.City == 'Hillsborough']

# %%
# plt.scatter(merged_df.lng, merged_df.lat, s=5, c = merged_df.Color)

# %%
lng, lat = merged_df.lng, merged_df.lat

# %%
merged_df['City, State'] = [merged_df.City[i] +', '+ merged_df.State[i] for i in range(len(merged_df))]

# %%
city_state = merged_df['City, State'].unique().tolist()

# %%
listofdf = [merged_df.loc[merged_df['City, State']==val, :] for val in merged_df['City, State'].unique()]

# %%
for i in range(len(listofdf)):
    listofdf[i] = listofdf[i].reset_index()

# %%
revised = []

for i in range(len(listofdf)):
    revised.append(listofdf[i].drop_duplicates(subset=['NCT Number', 'Color'], keep='first'))

# %%
# Create a frequency dictionary of each x-y pair
freq_dict = defaultdict(int)
for loni, lati in zip(lng, lat):
    freq_dict[(loni, lati)] += 1

# %%
# Separate points for jittering and truly unique points
jittered_x, jittered_y = [], []
unique_x, unique_y = [], []


def jitter_points(x, y, count, base_radius=.1):
    radius = base_radius * np.sqrt(count)  # Adjusting radius based on count
    theta = np.linspace(0, 2 * np.pi, count + 1)[:-1]
    x_jittered = np.round(x + radius * np.cos(theta), 4, None)
    y_jittered = np.round(y + radius * np.sin(theta), 4, None)
    return x_jittered, y_jittered

def unique_points(x, y):
    x_unique = np.round(x, 4, None)
    y_unique = np.round(y, 4, None)
    return x_unique, y_unique

# %%
jit= []

for i in range(len(revised)):
    if len(revised[i]) > 1:
        jit.append([])
        for j in range(len(revised[i])):
            jit[i].append([jitter_points(revised[i].iloc[j].lng, revised[i].iloc[j].lat, len(revised[i]))])
    elif len(revised[i]) == 1:
        jit.append([])
        for j in range(len(revised[i])):
            jit[i].append([unique_points(revised[i].lng, revised[i].lat)])

# %%
df = pd.DataFrame(merged_df[['NCT Number', 'Color']].value_counts().sort_values())

# %%
colors = [df.index[i][1] for i in range(len(df))]

# %%
pop = worldcities[worldcities['population'] > 200000]

# %%
pop = pop[pop['admin_name'] == 'Florida']

# %%
pop_lng, pop_lat, pop_city = pop.lng.tolist(), pop.lat.tolist(), pop.city.tolist()

# %%
plt.figure(figsize=(18, 16))

states_provinces = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_1_states_provinces_lines',
    scale='50m',
    facecolor='none')

ax = plt.axes(projection=ccrs.PlateCarree())

#ax.set_extent([merged_df.lng.min()*1, merged_df.lng.max()*1, merged_df.lat.min()*1, merged_df.lat.max()*1], ccrs.Geodetic())  US
ax.set_extent([-87.6349, -79.0311, 24.3963, 31.0007]) #Florida
ax.coastlines(color='lightgray')
ax.add_feature(cfeature.BORDERS, color='lightgray')
ax.add_feature(states_provinces, edgecolor='lightgray')
ax.add_feature(cfeature.OCEAN, color='royalblue', alpha=0.25)
ax.add_feature(cartopy.feature.LAKES, color='royalblue', alpha=0.25)

for i in range(len(jit)):
    plt.scatter(jit[i][0][0][0], jit[i][0][0][1], color = revised[i].Color, s = 10)
    plt.scatter(revised[i].lng, revised[i].lat, color='lightgreen', marker='o', s=2, label='Central Points')
    
for i in range(len(revised)):
    plt.plot((list(revised[i].lng), jit[i][0][0][0]), (list(revised[i].lat),jit[i][0][0][1]), c ='k', alpha=1, linewidth=.2 )


for i in range(len(pop_city)):
    plt.text(pop_lng[i], pop_lat[i], str(pop_city[i]), color='gray')
    
plt.title(cond+', '+term+', '+location+'\n', fontsize=16)
plt.axis('Off')
# plt.set_aspect('equal')  # Setting the aspect ratio to be equal


plt.scatter(x, y, color = 'k', s = 10)

# legend = merged_df['NCT Number'].value_counts().sort_values().plot(kind = 'barh', color = colors, align='center', width=0.6)
# axes[1].legend
# axes[1].grid(alpha=0.2)
# axes[1].set_xlabel('Number of Sites')
# fig.tight_layout()
plt.show()
# Out:
# C:\Users\robin\anaconda3\envs\clinicaltrials\lib\site-packages\cartopy\mpl\style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
merged_df['NCT Number'].value_counts().sort_values()
# Out:
# NCT Number
# NCT05675059      1
# NCT04760847      1
# NCT05969860      1
# NCT05000294      1
# NCT05440942      1
#               ...
# NCT05040360    292
# NCT04239573    293
# NCT04858334    365
# NCT04340141    383
# NCT04548752    493
# Name: count, Length: 97, dtype: int64

# %%
plt.figure(figsize=(4, 6))

legend = merged_df['NCT Number'].value_counts().sort_values().plot(kind = 'barh', color = colors, align='center', width=0.6)
plt.legend
plt.grid(alpha=0.2)
plt.xlabel('Number of Sites')
# fig.tight_layout()
plt.show()

# %%
merged_df.Interventions[merged_df['NCT Number'] == 'NCT04548752'].reset_index().iloc[0].tolist()[1].split('|')
# Out:
# ['Procedure: Biopsy',
#  'Procedure: Biospecimen Collection',
#  'Procedure: Computed Tomography',
#  'Procedure: Magnetic Resonance Imaging',
#  'Drug: Olaparib',
#  'Biological: Pembrolizumab']

# %%
merged_df.Interventions[merged_df['NCT Number'] == 'NCT04340141'].reset_index().iloc[0].tolist()[1].split('|')
# Out:
# ['Drug: Oxaliplatin',
#  'Drug: Irinotecan Hydrochloride',
#  'Drug: Leucovorin Calcium',
#  'Drug: Fluorouracil',
#  'Procedure: Resection',
#  'Other: Questionnaire Administration']

# %%
merged_df.Interventions[merged_df['NCT Number'] == 'NCT04858334'].reset_index().iloc[0].tolist()[1].split('|')
# Out:
# ['Procedure: Biospecimen Collection',
#  'Procedure: Computed Tomography',
#  'Procedure: Magnetic Resonance Imaging',
#  'Drug: Olaparib',
#  'Drug: Placebo Administration']

# %%
nct = pd.DataFrame(merged_df['NCT Number'].value_counts())
nct.head()
# Out:
#              count
# NCT Number
# NCT04548752    493
# NCT04340141    383
# NCT04858334    365
# NCT04239573    293
# NCT05040360    292

# %%
nct.index[:5]
# Out:
# Index(['NCT04548752', 'NCT04340141', 'NCT04858334', 'NCT04239573',
#        'NCT05040360'],
#       dtype='object', name='NCT Number')

# %%
intervention = []

for i in nct.index[:5]:
    intervention.append(merged_df.Interventions[merged_df['NCT Number'] == i].reset_index().iloc[0].tolist()[1].split('|'))

# %%
summary = pd.DataFrame({'NCT Number':nct.index[:5], 'Interventions':intervention})
summary['Interventions'] = [','.join(map(str, l)) for l in summary['Interventions']]

# %%
pd.set_option('display.max_colwidth', 0)

summary
# Out:
#     NCT Number  \
# 0  NCT04548752
# 1  NCT04340141
# 2  NCT04858334
# 3  NCT04239573
# 4  NCT05040360
#
#                                                                                                                                                                  Interventions
# 0  Procedure: Biopsy,Procedure: Biospecimen Collection,Procedure: Computed Tomography,Procedure: Magnetic Resonance Imaging,Drug: Olaparib,Biological: Pembrolizumab
# 1  Drug: Oxaliplatin,Drug: Irinotecan Hydrochloride,Drug: Leucovorin Calcium,Drug: Fluorouracil,Procedure: Resection,Other: Questionnaire Administration
# 2  Procedure: Biospecimen Collection,Procedure: Computed Tomography,Procedure: Magnetic Resonance Imaging,Drug: Olaparib,Drug: Placebo Administration
# 3  Procedure: Computed Tomography,Procedure: Endoscopic Ultrasound,Procedure: Magnetic Resonance Imaging,Other: Quality-of-Life Assessment,Other: Questionnaire Administration
# 4  Drug: Capecitabine,Drug: Temozolomide

# %%
summary.Interventions[0].split(',')
# Out:
# ['Procedure: Biopsy',
#  'Procedure: Biospecimen Collection',
#  'Procedure: Computed Tomography',
#  'Procedure: Magnetic Resonance Imaging',
#  'Drug: Olaparib',
#  'Biological: Pembrolizumab']
